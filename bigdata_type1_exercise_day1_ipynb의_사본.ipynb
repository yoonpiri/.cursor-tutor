# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonpiri/.cursor-tutor/blob/main/bigdata_type1_exercise_day1_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Day1
#
# - 시험문제에서 어려운 부분이 문제의 이해입니다.
# - 작업 방법을 단계별로 표현해 줄 때도 있었고, 아닐 때도 있어서 두 가지 방법으로 표기해 보았습니다.
# - **type-a, type-b 는 동일한 문제**입니다 ^^
# - 'a' 형식으로 문제가 출제 되어도 작업의 순서를 설계할 수 있도록 연습이 필요합니다.
# - 'a' 형식의 문제가 힘들다면 'b'의 문제형식을 참조합니다.

# %% [markdown]
# >> **본 문항들은 eduatoz.kr 소유이므로 절대 다른 곳에 공개, 공유를 금지하고 있습니다.**

# %% [markdown]
# #### type-a
#
# - 펭귄 데이터셋을 사용하여 다음을 구하여 출력하세요.

# %% [markdown]
# **1-1a) 펭귄 종에 따른 특성 비교 분석**
#
# species가 'Gentoo'인 데이터 중 flipper_length_mm이 상위 20% 이상인 개체들의 body_mass_g 평균값은?
# - flipper_length_mm 및 body_mass_g의 결측치는 species가 'Gentoo'인 표본의 평균값으로 채우기 하도록 합니다.
# - 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins04.csv')
print(df.isna().sum().to_frame().T)
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# 0        0       0               0              0                  2            2    0

# %%
# 여기에 풀이해 주세요
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins04.csv')

# %% [markdown]
# **1-2a) 펭귄의 성별 및 신체 특성 분석**
#
# body_mass_g 변수에서 이상치를 제거한 후(평균 ± 1.5*표준편차 기준), 남은 데이터 중 sex가 'Female'인 펭귄들의 bill_length_mm 평균값은?
# - 결측치를 포함한 모든 행을 제거하고 사용합니다.
# - 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female

# %%
# 여기에 풀이해 주세요
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')

# %% [markdown]
# **1-3a) 결측치 처리에 따른 데이터 특성 변화 분석**
#
# flipper_length_mm의 결측치를 해당 컬럼의 중앙값으로 대체한 후, '대체 전의 표준편차' - '대체 후의 표준편차' 값을 구하면?
# - 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female

# %%
# 여기에 풀이해 주세요
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')

# %% [markdown]
# **1-4a) 펭귄 종 간의 체중 차이에 따른 성별 분포 분석**
#
# species의 body_mass_g의 평균의 차이가 가장 큰 두 가지 품종의 sex이 Female의 표본 개수는?
# - 모든 결측치를 제거한 뒤 작업하도록 한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female

# %%
# 여기에 풀이해 주세요.
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')

# %% [markdown]
# **1-5a) 부리 길이 극단 그룹의 체중 비교 분석**
#
# bill_length_mm 기준으로 상위 20%와 하위 10%에 해당하는 개체들의 body_mass_g의 평균값을 각각 구한 뒤, 이 두 평균값의 차이(상위 20% 평균 - 하위 10% 평균)을 구하면?
# - 단, 모든 결측치를 제거한 후 작업한다.
# - 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins05.csv')
df.head(3)

# %%
# 여기에 풀이해 주세요.
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins05.csv')

# %% [markdown]
# #### type-b
#
# - 펭귄 데이터셋을 사용하여 다음을 구하여 출력하세요.

# %% [markdown]
# 펭귄 데이터셋을 사용하여 다음을 구하여 출력하세요.

# %% [markdown]
# **1-1b) 펭귄 종에 따른 특성 비교 분석**
#
# 펭귄의 날개 길이와 체중은 종(species)별 신체 특성을 파악하는 데 중요한 지표이다.
#
# 다음 조건에 따라 'Gentoo' 종 펭귄의 특성을 분석하시오.
# - species가 'Gentoo'인 데이터만을 대상으로 한다.
# - flipper_length_mm과 body_mass_g 변수의 결측치는 'Gentoo' 종의 평균값으로 대체한다.
# - 처리된 데이터 중 flipper_length_mm이 상위 20% 이상인 개체만 추출한다.
# - 이 개체들의 body_mass_g 평균값을 구하고, 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins04.csv')
print(df.isna().sum().to_frame().T)

# %%
# 여기에 풀이해 주세요
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins04.csv')

# %% [markdown]
# **1-2b) 펭귄의 성별 및 신체 특성 분석**
#
# 펭귄의 체중과 부리 길이 등은 성별에 따라 차이를 보이는 경우가 많다.
#
# 다음 조건에 따라 신체 특성을 분석하시오.
# - 결측치를 포함한 모든 행을 제거하고 사용한다.
# - body_mass_g 변수에서 이상치를 제거한다.
# > 이상치 기준: 평균 ± 1.5 × 표준편차
# - 이상치가 제거된 데이터 중 sex가 'Female'인 펭귄만 추출한다.
# - 남은 데이터에서 bill_length_mm의 평균값을 구하고, 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female

# %%
# 여기에 풀이해 주세요
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')

# %% [markdown]
# **1-3b) 결측치 처리에 따른 데이터 특성 변화 분석**
#
# 데이터 분석에서는 결측치 처리가 변수의 분포나 통계량에 어떤 영향을 미치는지 파악하는 것이 중요하다.
#
# 다음 조건에 따라 flipper_length_mm 변수의 특성 변화를 분석하시오.
# - flipper_length_mm 변수의 결측치를 해당 컬럼의 중앙값으로 대체한다.
# - 결측치 대체 전과 대체 후의 flipper_length_mm 표준편차를 각각 계산한다.
# - 두 표준편차의 차이(대체 전 - 대체 후)를 구하고, 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female

# %%
# 여기에 풀이해 주세요
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')

# %% [markdown]
# **1-4b) 펭귄 종 간의 체중 차이에 따른 성별 분포 분석**
#
# 펭귄의 종(species)에 따라 체중 특성이 달라질 수 있다.
#
# 다음 조건에 따라 종별 체중 차이와 성별 분포를 분석하시오.
# - 모든 결측치를 제거한 후 작업을 수행한다.
# - 종(species)별 body_mass_g 평균값을 계산한다.
# - 평균값 차이가 가장 큰 두 종을 찾는다.
# - 이 두 종에서 sex가 'Female'인 표본의 개수를 모두 합하여 구하시오.
# - 결과는 정수형으로 출력하시오.

# %%
# 데이터 확인
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female

# %%
# 여기에 풀이해 주세요.
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/bigdata/main/'
df = pd.read_csv(path + 'penguins01.csv')

# %% [markdown]
# **1-5b) 부리 길이 극단 그룹의 체중 비교 분석**
#
# 펭귄의 부리 길이(bill_length_mm)는 먹이 섭취 방식과 서식지 적응에 따라 차이가 날 수 있다.
#
# 다음 절차에 따라 문제를 해결하시오.
# - bill_length_mm 기준으로 상위 20%와 하위 10%에 해당하는 개체들을 각각 추출한다.
# - 두 그룹에서 body_mass_g의 평균값을 각각 계산하고,
# 이 두 평균값의 차이(상위 20% 평균 - 하위 10% 평균)를 구하시오.
# - 결과는 반올림하여 소수점 아래 3자리까지 출력한다.

# %%
# 데이터 확인
import pandas as pd
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins05.csv')
df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7                181         3750    Male
# 1  Adelie  Torgersen            39.5           17.4                186         3800  Female
# 2  Adelie  Torgersen            40.3           18.0                195         3250  Female

# %%
# 여기에 풀이해 주세요.
import pandas as pd
pd.set_option('display.width', 120)
path = 'https://raw.githubusercontent.com/Soyoung-Yoon/data_01/main/'
df = pd.read_csv(path+'penguins05.csv')
